# %% [markdown]
# # Proyek Analisis Data: E-Commerce Public Dataset
# - **Nama:** Rm Bagus Anindito Satrio Utomo
# - **Email:** bagusanindito41@gmail.com (Dicoding)
# - **Email:** m312d4ky2879@bangkit.academy (Bangkit)
# - **ID Dicoding:** rm_bagus_and

# %% [markdown]
# ---

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# 1. #### Identifikasi 5 *state* dengan pendapatan produk tertinggi. Kemudian, bandingkan tren pendapatan produk antara ke-5 *state* tersebut. Berikan analisis dari hasil tersebut.
#
# 2. #### Tentukan pengaruh antara jumlah order dengan banyak produk terjual terhadap ke-5 *state* dengan pendapatan terbanyak. Berikan analisis terhadap ke-5 *state* tersebut.

# %% [markdown]
# ---

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %% [markdown]
# Import library yang diperlukan:
# - Pandas,
# - Numpy,
# - Matplotlib, dan
# - Seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ---

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# #### Mengambil data frame yang dibutuhkan

# %%
df_customers = pd.read_csv("data/olist_customers_dataset.csv")
df_geolocation = pd.read_csv("data/olist_geolocation_dataset.csv")
df_orderItems = pd.read_csv("data/olist_order_items_dataset.csv")
df_orderPayments = pd.read_csv("data/olist_order_payments_dataset.csv")
df_orders = pd.read_csv("data/olist_orders_dataset.csv")
df_products = pd.read_csv("data/olist_products_dataset.csv")
df_category = pd.read_csv("data/product_category_name_translation.csv")

# %% [markdown]
# #### Checking dataframe

# %%
df_customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
df_geolocation.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
df_orderItems.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
df_orderPayments.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
df_orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
df_products.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
df_category.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %% [markdown]
# ----

# %% [markdown]
# ---

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# *Assessing `DataFrame Customers`*

# %%
df_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
#Cek missing values
df_customers.isna().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
# Identifikasi duplicate data
print("Duplicated Data: ",df_customers.duplicated().sum())
# Out:
# Duplicated Data:  0

# %% [markdown]
# *Assessing `DataFrame Geolocation`*

# %%
df_geolocation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  object
#  4   geolocation_state            1000163 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 38.2+ MB

# %%
#Cek missing values
df_geolocation.isna().sum()
# Out:
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64

# %%
# Identifikasi duplicate data
print("Duplicated Data: ",df_geolocation.duplicated().sum())
# Out:
# Duplicated Data:  261831

# %% [markdown]
# *Assessing `DataFrame Order Items`*

# %%
df_orderItems.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
#Cek missing values
df_orderItems.isna().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
# Identifikasi duplicate data
print("Duplicated Data: ",df_orderItems.duplicated().sum())
# Out:
# Duplicated Data:  0

# %% [markdown]
# *Assessing `DataFrame Order Payments`*

# %%
df_orderPayments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
#Cek missing values
df_orderPayments.isna().sum()
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %%
# Identifikasi duplicate data
print("Duplicated Data: ",df_orderPayments.duplicated().sum())
# Out:
# Duplicated Data:  0

# %% [markdown]
# *Assessing `DataFrame Orders`*

# %%
df_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
#Cek missing values
df_orders.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
# Identifikasi duplicate data
print("Duplicated Data: ",df_orders.duplicated().sum())
# Out:
# Duplicated Data:  0

# %% [markdown]
# *Assessing `DataFrame Products`*

# %%
df_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
#Cek missing values
df_products.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
# Identifikasi duplicate data
print("Duplicated Data: ",df_products.duplicated().sum())
# Out:
# Duplicated Data:  0

# %% [markdown]
# *Assessing `DataFrame Product Category Name Translation`*

# %%
df_category.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB

# %%
#Cek missing values
df_category.isna().sum()
# Out:
# product_category_name            0
# product_category_name_english    0
# dtype: int64

# %%
# Identifikasi duplicate data
print("Duplicated Data: ",df_category.duplicated().sum())
# Out:
# Duplicated Data:  0

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# *Table Cleaning: `df_orderItems`*

# %% [markdown]
# **Handling DataType**

# %%
df_orderItems['shipping_limit_date'] = pd.to_datetime(df_orderItems['shipping_limit_date'])

# %%
df_orderItems.dtypes
# Out:
# order_id                       object
# order_item_id                   int64
# product_id                     object
# seller_id                      object
# shipping_limit_date    datetime64[ns]
# price                         float64
# freight_value                 float64
# dtype: object

# %% [markdown]
# *Table Cleaning: `df_orders`*

# %% [markdown]
# **Handling missing values**

# %%
df_orders.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
df_orders.dropna(axis=0, inplace=True)

# %%
df_orders.isna().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# dtype: int64

# %% [markdown]
# **Handling DataType**

# %%
df_orders.dtypes
# Out:
# order_id                         object
# customer_id                      object
# order_status                     object
# order_purchase_timestamp         object
# order_approved_at                object
# order_delivered_carrier_date     object
# order_delivered_customer_date    object
# order_estimated_delivery_date    object
# dtype: object

# %%
df_orders['order_purchase_timestamp'] = pd.to_datetime(df_orders['order_purchase_timestamp'])
df_orders['order_approved_at'] = pd.to_datetime(df_orders['order_approved_at'])
df_orders['order_delivered_carrier_date'] = pd.to_datetime(df_orders['order_delivered_carrier_date'])
df_orders['order_delivered_customer_date'] = pd.to_datetime(df_orders['order_delivered_customer_date'])
df_orders['order_estimated_delivery_date'] = pd.to_datetime(df_orders['order_estimated_delivery_date'])

# %%
df_orders.dtypes
# Out:
# order_id                                 object
# customer_id                              object
# order_status                             object
# order_purchase_timestamp         datetime64[ns]
# order_approved_at                datetime64[ns]
# order_delivered_carrier_date     datetime64[ns]
# order_delivered_customer_date    datetime64[ns]
# order_estimated_delivery_date    datetime64[ns]
# dtype: object

# %% [markdown]
# *Table Cleaning: `df_products`*

# %% [markdown]
# **Handling missing values**

# %%
df_products.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
#Handle missing values ​​with the ffill method // fill in the missing values ​​with values ​​from the previous row
df_products['product_weight_g'].fillna(method='ffill', inplace=True)
df_products['product_length_cm'].fillna(method='ffill', inplace=True)
df_products['product_height_cm'].fillna(method='ffill', inplace=True)
df_products['product_width_cm'].fillna(method='ffill', inplace=True)
df_products['product_name_lenght'].fillna(method='ffill', inplace=True)
df_products['product_description_lenght'].fillna(method='ffill', inplace=True)
df_products['product_photos_qty'].fillna(method='ffill', inplace=True)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_25412\4114967565.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_products['product_weight_g'].fillna(method='ffill', inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_25412\4114967565.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_products['product_weight_g'].fillna(method='ffill', inplace=True)
# ...

# %%
# Handle missing values ​​with modus
mode_category = df_products['product_category_name'].mode()[0]
df_products['product_category_name'].fillna(value=mode_category, inplace=True)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_25412\207629733.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_products['product_category_name'].fillna(value=mode_category, inplace=True)

# %%
df_products.isna().sum()
# Out:
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              0
# product_length_cm             0
# product_height_cm             0
# product_width_cm              0
# dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ##### Identifikasi *states* dengan pendapatan produk tertinggi

# %%
revenue_states = pd.merge(df_orders,df_customers, how="left", on="customer_id")

revenue_states = pd.merge(revenue_states, df_orderPayments, how="left", on="order_id")

revenue_states.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 3    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 4    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
# Dari tabel di atas group by 'customer_state' dan jumlahkan 'payment_value' untuk setiap state
revenue_by_state = revenue_states.groupby('customer_state')['payment_value'].sum().reset_index()

# Urutkan dari pendapatan terbesar
revenue_by_state = revenue_by_state.sort_values(by='payment_value', ascending=False)
revenue_by_state.columns = ['State','Revenue']

# %% [markdown]
# #### Membuat tabel top 5 state

# %%
# Tabel top 5
top_five = revenue_by_state.head(5)
top_five = pd.DataFrame(top_five)
top_five
# Out:
#    State     Revenue
# 25    SP  5768355.09
# 18    RJ  2055878.41
# 10    MG  1819029.99
# 22    RS   861054.35
# 17    PR   781919.55

# %% [markdown]
# ##### Membuat fungsi untuk menghitung pendapatan bulanan untuk *spesific state* / Year-Month

# %%
# Gunakan tabel revenue_state, state column, dan specific states sebagai parameter

def calculate_monthly_revenue(revenue_states, state_column, states=None):
    # Filter DataFrame berdasarkan state.
    if states:
        revenue_states = revenue_states[revenue_states[state_column].isin(states)]

    # ekstrak tahun dan bulan dari kolom 'order_purchase_timestamp'
    revenue_states['year'] = revenue_states['order_purchase_timestamp'].dt.year
    revenue_states['month'] = revenue_states['order_purchase_timestamp'].dt.month

    # kelompokkan tahun, bulan, dan state dan sum revenua
    group_columns = ['year', 'month']
    if state_column in revenue_states.columns:
        group_columns.append(state_column)
    monthly_revenue = revenue_states.groupby(group_columns)['payment_value'].sum().reset_index()
    
    # urutkan hasil
    monthly_revenue = monthly_revenue.sort_values(by=['customer_state', 'year', 'month']).reset_index(drop=True)

    # membuat year-month
    monthly_revenue['year_month'] = monthly_revenue['year'].astype(str) + '-' + monthly_revenue['month'].astype(str)   
    monthly_revenue.columns = ['year', 'month', 'state', 'revenue', 'year_month']
    monthly_revenue = monthly_revenue[monthly_revenue['year_month'] != '2016-12']
    return monthly_revenue

# kalkulasi pendapatan per bulan
monthly_revenue_SP = calculate_monthly_revenue(revenue_states, 'customer_state', states=['SP'])
monthly_revenue_RJ = calculate_monthly_revenue(revenue_states, 'customer_state', states=['RJ'])
monthly_revenue_MG = calculate_monthly_revenue(revenue_states, 'customer_state', states=['MG'])
monthly_revenue_RS = calculate_monthly_revenue(revenue_states, 'customer_state', states=['RS'])
monthly_revenue_PR = calculate_monthly_revenue(revenue_states, 'customer_state', states=['PR'])
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_25412\2133067243.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   revenue_states['year'] = revenue_states['order_purchase_timestamp'].dt.year
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_25412\2133067243.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   revenue_states['month'] = revenue_states['order_purchase_timestamp'].dt.month
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_25412\2133067243.py:9: SettingWithCopyWarning:
# ...

# %%
#cek
monthly_revenue_MG.head()
# Out:
#    year  month state   revenue year_month
# 0  2016     10    MG   4959.82    2016-10
# 1  2017      1    MG  18010.21     2017-1
# 2  2017      2    MG  33686.91     2017-2
# 3  2017      3    MG  48493.85     2017-3
# 4  2017      4    MG  44909.30     2017-4

# %% [markdown]
# ### Membuat tabel untuk scatter plot

# %%
order_states = revenue_states[['order_id', 'order_status', 'order_purchase_timestamp', 'customer_state']]

# %%
# Merge products table and products_eng table, stored in products_merged
products_merged = pd.merge(df_products, df_category, how='left', on='product_category_name')

# Merge revenue_states table and order_items table, stored in revenue_order_items
revenue_order_items = pd.merge(revenue_states, df_orderItems, how='left', on='order_id')

# Merge revenue_order_items table and products_merged table, stored in revenue_products
revenue_products = pd.merge(revenue_order_items, products_merged, how='left', on='product_id')

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:
#
# #### Identifikasi 5 *state* dengan pendapatan produk tertinggi. Kemudian, bandingkan tren pendapatan produk antara ke-5 *state* tersebut. Berikan analisis dari hasil tersebut.

# %% [markdown]
# **Grafik 1**<br>
# **Bar Diagram**

# %%
# Mengatur ukuran dan pembagian subplot
plt.figure(figsize=(13, 6))


sns.barplot(data=top_five, x="State", y="Revenue",errorbar=None)
plt.xlabel("State")
plt.ylabel("Pendapatan")
plt.title("Perbandingan Pendapatan Produk terhadap State")

# Menampilkan plot
plt.tight_layout()  # Mengatur layout subplot agar tidak tumpang tindih
plt.show()

# %% [markdown]
# **Grafik 2**<br>
# **Line chart untuk ke-5 *State***

# %%
# Plotting all lines on the same figure
plt.figure(figsize=(15,6))
sns.lineplot(data=monthly_revenue_SP, x='year_month', y='revenue', marker='o', color='black', markerfacecolor='black', markersize=7, label='SP')
sns.lineplot(data=monthly_revenue_RJ, x='year_month', y='revenue', marker='o', color='blue', markerfacecolor='blue', markersize=7, label='RJ')
sns.lineplot(data=monthly_revenue_MG, x='year_month', y='revenue', marker='o', color='green', markerfacecolor='green', markersize=7, label='MG')
sns.lineplot(data=monthly_revenue_RS, x='year_month', y='revenue', marker='o', color='red', markerfacecolor='red', markersize=7, label='RS')
sns.lineplot(data=monthly_revenue_PR, x='year_month', y='revenue', marker='o', color='orange', markerfacecolor='orange', markersize=7, label='PR')

# Adjusting labels and title
plt.title('REVENUE TREND')
plt.ylabel('REVENUE')
plt.xlabel('YEAR-MONTH')
plt.ylim(0, 500000)
plt.grid(True)

# Adding legend
plt.legend()

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()

# %% [markdown]
# **Grafik 3<br>**
# **Line chart untuk membandingkan tren grafik**

# %%
# Set the figure size
plt.figure(figsize=(18,20))

# Subplot 1
plt.subplot(5, 1, 1)
sns.lineplot(data=monthly_revenue_SP, x='year_month', y='revenue',marker='o', color='black', markerfacecolor='black', markersize=7)
plt.title('REVENUE TREND SP')
plt.ylabel('REVENUE')
plt.xlabel('YEAR-MONTH')
plt.grid(True)

# Subplot 2
plt.subplot(5, 1, 2)
sns.lineplot(data=monthly_revenue_RJ, x='year_month', y='revenue',marker='o', color='blue', markerfacecolor='blue', markersize=7)
plt.title('REVENUE TREND RJ')
plt.ylabel('REVENUE')
plt.xlabel('YEAR-MONTH')
plt.grid(True)

# Subplot 3
plt.subplot(5, 1, 3)
sns.lineplot(data=monthly_revenue_MG, x='year_month', y='revenue',marker='o', color='green', markerfacecolor='green', markersize=7)
plt.title('REVENUE TREND MG')
plt.ylabel('REVENUE')
plt.xlabel('YEAR-MONTH')
plt.grid(True)

# Subplot 3
plt.subplot(5, 1, 4)
sns.lineplot(data=monthly_revenue_RS, x='year_month', y='revenue',marker='o', color='red', markerfacecolor='red', markersize=7)
plt.title('REVENUE TREND RS')
plt.ylabel('REVENUE')
plt.xlabel('YEAR-MONTH')
plt.grid(True)

# Subplot 3
plt.subplot(5, 1, 5)
sns.lineplot(data=monthly_revenue_PR, x='year_month', y='revenue',marker='o', color='orange', markerfacecolor='orange', markersize=7)
plt.title('REVENUE TREND PR')
plt.ylabel('REVENUE')
plt.xlabel('YEAR-MONTH')
plt.grid(True)

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()

# %% [markdown]
# ### Pertanyaan 2:
#
# #### Tentukan pengaruh antara jumlah order dengan banyak produk terjual terhadap ke-5 *state* dengan pendapatan terbanyak. Berikan analisis terhadap ke-5 *state* tersebut.

# %% [markdown]
# **Cek korelasi**

# %%
# Group data and count orders and products per state
grouped_data = revenue_products.groupby('customer_state').agg(
    num_orders=pd.NamedAgg(column='order_id', aggfunc='nunique'),
    num_products=pd.NamedAgg(column='product_id', aggfunc='nunique')
).reset_index()

# Filtering using DataFrame.loc[]
top_5_states = ['SP','RJ','MG','RS','PR']
group_of_top_5_states = grouped_data.loc[grouped_data['customer_state'].isin(top_5_states)].reset_index(drop=True)

# Calculate the correlation coefficient
num_orders = group_of_top_5_states.loc[:,'num_orders']
num_products = group_of_top_5_states.loc[:,'num_products']

correlation_matrix = np.corrcoef(num_products, num_orders)
correlation_top_5_states = correlation_matrix[0, 1]

print(group_of_top_5_states)
print("Correlation:", correlation_top_5_states)
# Out:
#   customer_state  num_orders  num_products
# 0             MG       11352          7209
# 1             PR        4923          3703
# 2             RJ       12351          7672
# 3             RS        5342          3936
# 4             SP       40489         18702
# Correlation: 0.9975620706758875

# %% [markdown]
# **Scatter plot**

# %%
# Create a scatter plot using Seaborn
plt.figure(figsize=(13, 6))
sns.scatterplot(data=group_of_top_5_states, x='num_products', y='num_orders', hue='customer_state')

# Add the correlation line using Seaborn's regplot
sns.regplot(data=group_of_top_5_states, x='num_products', y='num_orders', scatter=False, color='blue', line_kws={"linewidth": 1})

# Customize the plot (optional)
plt.title('Korelasi antara Jumlah Order dengan Total Produk Terjual terhadap k-5 state')
plt.xlabel('Total Produk Terjual')
plt.ylabel('Jumlah Order')
plt.legend(title='State')

# Add the correlation coefficient as text to the plot
plt.text(10000, 26500, f'Correlation: {correlation_top_5_states:.3f}', fontsize=9, color='blue')

# Show the plot
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ### Conclusion 1:

# %% [markdown]
# Dari hasil di atas, didapatkan grafik untuk ke-5 *state* dengan pendapatan produk tertinggi, yakni SP, RJ, MG, RS, dan PR (grafik 1). Dapat dilihat pada grafik 2, didapatkan perbandingan pendapatan produk per bulan yang signifikan antara *state* SP dengan ke-4 *state* lainnya. Untuk *state* RJ memiliki kemiripan pendapatan produk per bulan dengan *state* MG. Sedangkan untuk *state* RS memmiliki kemiripan pendapatan produk per bulan dengan *state* PR.<br><br>
# Sedangkan pada grafik 3, ditampilkan pola grafik tren untuk ke-5 *state*. Dari tren tersebut, didapatkan pola yang similar antara ke-5 *state*, yang mana terjadi kenaikan pada setiap tahunnya dengan lonjakan pendapatan produk tertinggi antara 2017-10 hingga 2017-11 pada ke-5 *state*.<br><br>
# Sehingga, dari pernyataan di atas dapat diambil kesimpulan:
# 1. SP, RJ, MG, RS, dan PR merupakan top 5 untuk *state* dengan jumlah pendapatan produk tertinggi
# 2. Banyaknya pendapatan produk per bulan bisa dipengaruhi oleh geolokasi (khususnya *state*)
# 2. Pola tren ke-5 *state* memiliki kesamaan, sehingga persentase kenaikan pendapatan produk untuk ke-5 *state* tersebut tidak berbeda jauh untuk setiap bulannya.<br>
#
# Dengan mengetahui hal-hal tersebut, strategi bisnis dapat difokuskan untuk mengoptimalkan layanan terutama distribusi produk pada ke-5 daerah ini. Selain itu, lonjakan tren akibat *event* tertentu juga dapat menjadi pertimbangan dalam mengambil keputusan.

# %% [markdown]
# ### Conclusion 2:

# %% [markdown]
# Dari hasil di atas, didapatkan grafik untuk menjelaskan korelasi antara jumlah order dan produk terjual terhadap pendapatan produk.<br><br>
# Jumlah order dan produk terjual memiliki pengaruh yang signifikan (yakni = 0,998) terhadap pendapatan pada 5 *state* dengan pendapatan terbanyak. Artinya, besar jumlah order dan pendapatan produk akan berbeda di setiap daerah. Semakin banyak order maka semakin banyak pula pendapatan produknya. *State* dengan jumlah order dan produk terjual yang tinggi (yakni SP) memiliki market potential yang besar dan perlu diprioritaskan untuk ekspansi dan promosi.
